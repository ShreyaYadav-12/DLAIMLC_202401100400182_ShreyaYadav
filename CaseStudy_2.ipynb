# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import datasets,layers,models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
import matplotlib.pyplot as plt

# %%
(x_train,y_train),(x_test,y_test)=datasets.cifar10.load_data()

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %%
model=models.Sequential()

# %%
model.add(layers.Input(shape=(32,32,3)))

# %%
model.add(layers.Conv2D(32,(3,3),activation='relu',padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(32,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.25))

# %%
model.add(layers.Conv2D(64,(3,3),activation='relu',padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.25))

# %%
model.add(layers.Flatten())

# %%
model.add(layers.Dense(128,activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10,activation='softmax'))

# %%
model.compile(
optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy']
)

# %%
model.fit(x_train,y_train,epochs=8,
validation_data=(x_test,y_test))
# Out:
# Epoch 1/8
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 153s 98ms/step - accuracy: 0.3496 - loss: 1.7194 - val_accuracy: 0.4944 - val_loss: 1.4104
# Epoch 2/8
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 147s 94ms/step - accuracy: 0.4614 - loss: 1.4551 - val_accuracy: 0.5435 - val_loss: 1.2858
# Epoch 3/8
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 150s 96ms/step - accuracy: 0.4912 - loss: 1.3780 - val_accuracy: 0.6019 - val_loss: 1.1316
# Epoch 4/8
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 200s 94ms/step - accuracy: 0.5130 - loss: 1.3209 - val_accuracy: 0.5803 - val_loss: 1.2410
# Epoch 5/8
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 153s 98ms/step - accuracy: 0.5353 - loss: 1.2601 - val_accuracy: 0.6165 - val_loss: 1.0920
# Epoch 6/8
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 201s 97ms/step - accuracy: 0.5545 - loss: 1.2213 - val_accuracy: 0.6431 - val_loss: 1.0229
# Epoch 7/8
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 154s 98ms/step - accuracy: 0.5705 - loss: 1.1764 - val_accuracy: 0.6344 - val_loss: 1.0680
# Epoch 8/8
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 202s 98ms/step - accuracy: 0.5888 - loss: 1.1315 - val_accuracy: 0.6175 - val_loss: 1.1143

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print("Test accuracy:",test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6175 - loss: 1.1143
# Test accuracy: 0.6175000071525574
